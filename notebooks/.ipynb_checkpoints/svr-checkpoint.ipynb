# %%
from sklearn.svm import SVR
import numpy as np
from numpy import loadtxt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import sys
sys.path.append('..')
db = loadtxt('../darwin.txt', delimiter=',')
db = [round(i,1) for i in db]

# %%
num_features = 5
X = list()
y = db[num_features:len(db)]
for i in range(len(db)-num_features):
    p = list()
    for j in range(num_features):
        p.append(db[i+num_features-j])
    X.append(p)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.02, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-37cdc0778bfc> in <module>()
# ----> 1 _, _, y_train, y_test = train_test_split(_, y, test_size=0.02, random_state=42)
#
# C:\Users\Tirth\Anaconda2\lib\site-packages\sklearn\model_selection\_split.pyc in train_test_split(*arrays, **options)
#    1687         test_size = 0.25
#    1688
# -> 1689     arrays = indexable(*arrays)
#    1690
#    1691     if stratify is not None:
#
# C:\Users\Tirth\Anaconda2\lib\site-packages\sklearn\utils\validation.pyc in indexable(*iterables)
#     204         else:
#     205             result.append(np.array(X))
# --> 206     check_consistent_length(*result)
#     207     return result
#     208
#
# C:\Users\Tirth\Anaconda2\lib\site-packages\sklearn\utils\validation.pyc in check_consistent_length(*arrays)
#     175     """
#     176
# --> 177     lengths = [_num_samples(X) for X in arrays if X is not None]
#     178     uniques = np.unique(lengths)
#     179     if len(uniques) > 1:
#
# C:\Users\Tirth\Anaconda2\lib\site-packages\sklearn\utils\validation.pyc in _num_samples(x)
#     124         if len(x.shape) == 0:
#     125             raise TypeError("Singleton array %r cannot be considered"
# --> 126                             " a valid collection." % x)
#     127         return x.shape[0]
#     128     else:
#
# TypeError: Singleton array 0.24003156946238935 cannot be considered a valid collection.

# %%
clf = SVR(C=1.0, epsilon=0.2)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
mean_squared_error(y_test, y_pred)
# Out:
# 0.24003156946238935

# %%
plt.plot(range(len(y_test)), y_test,'r');
plt.plot(range(len(y_pred)), y_pred,'b');
plt.show();
